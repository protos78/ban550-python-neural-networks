# %%
1
# Out:
# 1

# %%
1.3
# Out:
# 1.3

# %%
1+2
# Out:
# 3

# %%
2*3
# Out:
# 6

# %%
4/5
# Out:
# 0.8

# %%
10/5
# Out:
# 2.0

# %%
2+3*4+5
# Out:
# 19

# %%
(2+3)*4+5
# Out:
# 25

# %%
10 % 3
# Out:
# 1

# %%
x = 2
y = 3

# %%
x + y
# Out:
# 5

# %%
y = 5

# %%
var_1 =5

# %%
"This is a sentence"
# Out:
# 'This is a sentence'

# %%
"""I can't go"""
# Out:
# "I can't go"

# %%
s = 'hello world'

# %%
s[0]
# Out:
# 'h'

# %%
s[6]
# Out:
# 'w'

# %%
s[6:]
# Out:
# 'world'

# %%
s[2:6]
# Out:
# 'llo '

# %%
s[:6]
# Out:
# 'hello '

# %%
name = 'Ferdi'
number = 97

# %%
print('Hello, my name is {one} and my favorite number is {two}'.format(two=number, one=name))
# Out:
# Hello, my name is Ferdi and my favorite number is 97

# %%
myList = [1,2,3,4,5]

# %%
myList
# Out:
# [1, 2, 3, 4, 5]

# %%
type(myList)
# Out:
# list

# %%
type(name)
# Out:
# str

# %%
myList[0]
# Out:
# 1

# %%
myList[1:3]
# Out:
# [2, 3]

# %%
myList[0] = 99

# %%
myList
# Out:
# [99, 2, 3, 4, 5]

# %%
anotherList = ['a',2,'c','hello',9]

# %%
myList.append(50)

# %%
myList
# Out:
# [99, 2, 3, 4, 5, 50]
